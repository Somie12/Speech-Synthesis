# %% [markdown]
# <a href="https://colab.research.google.com/github/Somie12/Speech-Synthesis/blob/main/Generating%20Speech%20from%20TTS/Rany2_edge_tts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install edge-tts
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for srt: filename=srt-3.5.3-py3-none-any.whl size=22428 sha256=eb88c07f998ace0a915139e376e0bcac6329350744f2f7ca4e83690c9e6fd766
#   Stored in directory: /root/.cache/pip/wheels/1f/43/f1/23ee9119497fcb57d9f7046fbf34c6d9027c46a1fa7824cf08
# Successfully built srt
# ...

# %%
! edge-tts --text "Hello, world!" --write-media hello.mp3 --write-subtitles hello.srt

# %%
# !sudo apt-get update
# !sudo apt-get install mpv
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [66.7 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,311 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,663 kB]
# Get:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# ...

# %%
! edge-playback --text "Hello, world!"
# Out:
# Media file: /tmp/tmprrqj0rfz.mp3
# Subtitle file: /tmp/tmpw5vt3yha.srt
#
# [ffmpeg/demuxer] mp3: Estimating duration from bitrate, this may be inaccurate
#  (+) Audio --aid=1 (mp3 1ch 24000Hz)
#  (+) Subs  --sid=1 'tmpw5vt3yha.srt' (subrip) (external)
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# [ao/alsa] Playback open error: No such file or directory
# ...

# %%
# !edge-tts --text "Hello, world!" --write-media hello.mp3 --write-subtitles hello.srt

# %%
! edge-tts --list-voices
# Out:
# Name                               Gender    ContentCategories      VoicePersonalities
# ---------------------------------  --------  ---------------------  --------------------------------------
# af-ZA-AdriNeural                   Female    General                Friendly, Positive
# af-ZA-WillemNeural                 Male      General                Friendly, Positive
# am-ET-AmehaNeural                  Male      General                Friendly, Positive
# am-ET-MekdesNeural                 Female    General                Friendly, Positive
# ar-AE-FatimaNeural                 Female    General                Friendly, Positive
# ar-AE-HamdanNeural                 Male      General                Friendly, Positive
# ar-BH-AliNeural                    Male      General                Friendly, Positive
# ar-BH-LailaNeural                  Female    General                Friendly, Positive
# ar-DZ-AminaNeural                  Female    General                Friendly, Positive
# ...

# %%
! edge-tts --voice ar-EG-SalmaNeural --text "مرحبا كيف حالك؟" --write-media hello_in_arabic.mp3 --write-subtitles hello_in_arabic.srt

# %%
! edge-tts --rate=-50% --text "Hello, world!" --write-media hello_with_rate_lowered.mp3 --write-subtitles hello_with_rate_lowered.srt
! edge-tts --volume=-50% --text "Hello, world!" --write-media hello_with_volume_lowered.mp3 --write-subtitles hello_with_volume_lowered.srt
! edge-tts --pitch=-50Hz --text "Hello, world!" --write-media hello_with_pitch_lowered.mp3 --write-subtitles hello_with_pitch_lowered.srt

# %%
from IPython.display import Audio

# %%
! pip show IPython
# Out:
# Name: ipython
# Version: 7.34.0
# Summary: IPython: Productive Interactive Computing
# Home-page: https://ipython.org
# Author: The IPython Development Team
# Author-email: ipython-dev@python.org
# License: BSD
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: backcall, decorator, jedi, matplotlib-inline, pexpect, pickleshare, prompt-toolkit, pygments, setuptools, traitlets
# Required-by: bigquery-magics, cufflinks, datascience, google-colab, ipykernel, ipyparallel, ipython-sql, ipywidgets, jupyter-console, spanner-graph-notebook

# %%
from IPython.display import Audio

Audio("hello.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio

# Your edge-tts command to generate the audio file
! edge-tts --text "Hello, world!" --write-media hello.mp3 --write-subtitles hello.srt

# Play the audio using IPython.display.Audio
Audio("hello.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio

# Generate audio with modified rate, volume, and pitch
! edge-tts --rate=-50% --text "Hello, world!" --write-media hello_with_rate_lowered.mp3 --write-subtitles hello_with_rate_lowered.srt
! edge-tts --volume=-50% --text "Hello, world!" --write-media hello_with_volume_lowered.mp3 --write-subtitles hello_with_volume_lowered.srt
! edge-tts --pitch=-50Hz --text "Hello, world!" --write-media hello_with_pitch_lowered.mp3 --write-subtitles hello_with_pitch_lowered.srt

# Play each generated audio file
Audio("hello_with_rate_lowered.mp3", autoplay=True)
Audio("hello_with_volume_lowered.mp3", autoplay=True)
Audio("hello_with_pitch_lowered.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio

# Specify the Chinese voice
voice = "zh-CN-XiaoxiaoNeural"  # Example: Xiaoxiao Neural voice for Mandarin Chinese

# Chinese text to be spoken
text = "你好，世界！"  # "Hello, world!" in Mandarin Chinese

# Generate the audio file
! edge-tts --voice {voice} --text "{text}" --write-media hello_chinese.mp3 --write-subtitles hello_chinese.srt

# Play the audio
Audio("hello_chinese.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio

# Specify the Hindi voice
voice = "hi-IN-SwaraNeural"  # Swara Neural voice for Hindi

# Hindi text to be spoken
text = "नमस्ते दुनिया!"  # "Hello, world!" in Hindi

# Generate the audio file
! edge-tts --voice {voice} --text "{text}" --write-media hello_hindi.mp3 --write-subtitles hello_hindi.srt

# Play the audio
Audio("hello_hindi.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # New Section

# %%
from IPython.display import Audio

# Specify the Hindi voice
voice = "hi-IN-SwaraNeural"  # Swara Neural voice for Hindi

# Hindi text to be spoken
text = " दिक्ये निश्चत रूप से एक मध्यम बर्गी परीवार से थे और ..."

# Generate the audio file
! edge-tts --voice {voice} --text "{text}" --write-media hello_hindi.mp3 --write-subtitles hello_hindi.srt

# Play the audio
Audio("hello_hindi.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio

# Specify the Mandarin Chinese voice
voice = "zh-CN-XiaoxiaoNeural"  # Xiaoxiao Neural voice for Mandarin Chinese

# Mandarin Chinese text to be spoken
text = "作者有聲有色描繪的辛普森案件,就是普通法意義上的公正訴訟,因為雙方都得到了他們原有的地位。辯方律師團排除了任何的案件。"

# Generate the audio file
! edge-tts --voice {voice} --text "{text}" --write-media hello_chinese.mp3 --write-subtitles hello_chinese.srt

# Play the audio
Audio("hello_chinese.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio

# Specify an English voice
voice = "en-US-AriaNeural"  # Example: Aria Neural voice for US English

# English text to be spoken
text = " This book is truly a gift to the Body of Christ. Each verse is so carefully unwrapped, revealing the overwhelming love of God to us, His beloved."
# Generate the audio file
! edge-tts --voice {voice} --text "{text}" --write-media hello_english.mp3 --write-subtitles hello_english.srt

# Play the audio
Audio("hello_english.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
